# %%
import sys
sys.path.append('..')
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sfp_nsdsyn import *
import warnings
import itertools
import matplotlib as mpl
import pyrtools as pt
warnings.filterwarnings("ignore", category=UserWarning)
pd.options.mode.chained_assignment = None
# %load_ext autoreload
# %autoreload 2
fig_dir = '/Users/jh7685/Desktop'
import sfp
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
stim = sfp.stimuli.log_polar_grating(1200, w_r=14, w_a=14, scale_factor=1)
pt.imshow(stim);
plt.savefig(os.path.join(fig_dir, 'log_polar_grating.eps'))
# Out:
# <PyrFigure size 1200x1500 with 1 Axes>

# %%
stim.shape
# Out:
# (512, 512)
