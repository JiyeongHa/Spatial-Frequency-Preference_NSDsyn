# %%
import sys
sys.path.append('/Users/jh7685/Dropbox/NYU/Projects/SF/Scripts')
import numpy as np
import make_df as mdf
import sfp_nsd_utils as utils
import binning_eccen as binning
import first_level_analysis as fitting
import plot_1D_model_results as plotting
import pandas as pd
# %load_ext autoreload
# %autoreload 2

# %%
## load all data
subj_list = np.arange(1,9)
all_subj_avg_df = binning.get_all_subj_df(subjects_to_run=subj_list, dv_to_group=["vroinames", "eccrois", "freq_lvl"])

# %%
binning.scatterplot_2D(all_subj_avg_df, subj='avg')

# %%
subj_list = np.arange(1,9)
all_subj_df = binning.get_all_subj_df(subjects_to_run=subj_list, dv_to_group=["subj","vroinames", "eccrois", "freq_lvl"], save_avg_df=True)

# %%
all_subj_df.head()
# Out:
#      subj vroinames  eccrois  freq_lvl  avg_betas  local_ori   local_sf
# 0  subj01        V1      1.0         0   1.404251    1.54996   3.049521
# 1  subj01        V1      1.0         1   1.352611    1.54996   5.467465
# 2  subj01        V1      1.0         2   1.147461    1.54996  10.411715
# 3  subj01        V1      1.0         3   0.998912    1.57303  19.268526
# 4  subj01        V1      1.0         4   0.911174    1.54996  36.179394

# %%
output_df, loss_df = fitting.fit_1D_model_all_subj(all_subj_df)
# Out:
# epoch 500 loss 0.019
# epoch 1000 loss 0.018
# epoch 1500 loss 0.018
# epoch 2000 loss 0.017
# epoch 2500 loss 0.017
# epoch 3000 loss 0.017
# epoch 3500 loss 0.017
# epoch 4000 loss 0.017
# epoch 4500 loss 0.017
# epoch 5000 loss 0.017
# *** subj01 V1 ecc 1.0 finished ***
# amplitude 1.39, mode 4.26, sigma 3
#
# epoch 500 loss 0.044
# epoch 1000 loss 0.044
# epoch 1500 loss 0.044
# epoch 2000 loss 0.044
# epoch 2500 loss 0.044
# epoch 3000 loss 0.044
# epoch 3500 loss 0.044
# epoch 4000 loss 0.044
# epoch 4500 loss 0.044
# epoch 5000 loss 0.044
# *** subj01 V1 ecc 2.0 finished ***
# amplitude 2.63, mode 2.69, sigma 3
#
# epoch 500 loss 0.004
# epoch 1000 loss 0.004
# epoch 1500 loss 0.004
# epoch 2000 loss 0.004
# epoch 2500 loss 0.004
# epoch 3000 loss 0.004
# epoch 3500 loss 0.004
# epoch 4000 loss 0.004
# epoch 4500 loss 0.004
# epoch 5000 loss 0.004
# *** subj01 V1 ecc 3.0 finished ***
# amplitude 2.85, mode 1.99, sigma 3
#
# epoch 500 loss 0.006
# epoch 1000 loss 0.006
# ...

# %%
sub_df = all_subj_df.query('subj == "subj01"')
sub_df
# Out:
#        subj vroinames  eccrois  freq_lvl  avg_betas  local_ori   local_sf
# 0    subj01        V1      1.0         0   1.404251   1.549960   3.049521
# 1    subj01        V1      1.0         1   1.352611   1.549960   5.467465
# 2    subj01        V1      1.0         2   1.147461   1.549960  10.411715
# 3    subj01        V1      1.0         3   0.998912   1.573030  19.268526
# 4    subj01        V1      1.0         4   0.911174   1.549960  36.179394
# ..      ...       ...      ...       ...        ...        ...        ...
# 115  subj01       V4v      5.0         1   0.771862   1.572489   0.279138
# 116  subj01       V4v      5.0         2   0.779135   1.572489   0.531563
# 117  subj01       V4v      5.0         3   0.609626   1.566283   0.983742
# 118  subj01       V4v      5.0         4   0.780502   1.572489   1.847115
# 119  subj01       V4v      5.0         5   0.688359   1.572489   3.428449
#
# [120 rows x 7 columns]

# %%
merged_df, grid = plotting.merge_and_plot(subj_to_run=np.arange(1,9), fitting_df=output_df, subj_df=all_subj_df, save_fig=False, save_file_name='_alpha_p01.png')

# %%
alpha_val = 0.01
output_df, loss_df = fitting.pytorch_1D_model_fitting(all_subj_df, initial_val=[1, 1, 1], epoch=5000, alpha=alpha_val, save_loss_df=False)
# Out:
# epoch 0 loss 1.027
# epoch 500 loss 0.02
# epoch 1000 loss 0.019
# epoch 1500 loss 0.019
# epoch 2000 loss 0.018
# epoch 2500 loss 0.018
# epoch 3000 loss 0.018
# epoch 3500 loss 0.017
# epoch 4000 loss 0.017
# epoch 4500 loss 0.017
# epoch 4999 loss 0.017
# *** subj01 V1 ecc 1.0 finished ***
# amplitude 1.39, mode 4.18, sigma 3
#
# epoch 0 loss 3.976
# epoch 500 loss 0.047
# epoch 1000 loss 0.044
# epoch 1500 loss 0.044
# epoch 2000 loss 0.044
# epoch 2500 loss 0.044
# epoch 3000 loss 0.044
# epoch 3500 loss 0.044
# epoch 4000 loss 0.044
# epoch 4500 loss 0.044
# epoch 4999 loss 0.044
# *** subj01 V1 ecc 2.0 finished ***
# amplitude 2.63, mode 2.69, sigma 3
#
# epoch 0 loss 4.049
# epoch 500 loss 0.005
# epoch 1000 loss 0.004
# epoch 1500 loss 0.004
# epoch 2000 loss 0.004
# epoch 2500 loss 0.004
# epoch 3000 loss 0.004
# epoch 3500 loss 0.004
# epoch 4000 loss 0.004
# epoch 4500 loss 0.004
# epoch 4999 loss 0.004
# *** subj01 V1 ecc 3.0 finished ***
# ...

# %%
loss_df
# Out:
#        subj vroinames  eccrois  alpha n_epoch start_loss     final_loss
# 0    subj01        V1      1.0   0.01    5000  1.0269432    0.017060032
# 1    subj01        V1      2.0   0.01    5000  3.9762897     0.04440713
# 2    subj01        V1      3.0   0.01    5000   4.049287    0.004295833
# 3    subj01        V1      4.0   0.01    5000  6.1551094   0.0060034255
# 4    subj01        V1      5.0   0.01    5000  3.6382396  0.00042034133
# ..      ...       ...      ...    ...     ...        ...            ...
# 155  subj08       V4v      1.0   0.01    5000  0.8850493   0.0016029938
# 156  subj08       V4v      2.0   0.01    5000  0.7086129  0.00055257126
# 157  subj08       V4v      3.0   0.01    5000  6.9183235    0.006943983
# 158  subj08       V4v      4.0   0.01    5000  3.8842833    0.014377073
# 159  subj08       V4v      5.0   0.01    5000  3.3809779   0.0043012626
#
# [160 rows x 7 columns]

# %%
first_level_output_df = utils.load_all_subj_df(subjects_to_run=subj_list,
                                               df_dir='/Volumes/server/Projects/sfp_nsd/natural-scenes-dataset/derivatives/first_level_analysis',
                                               df_name='results_1D_model.csv')

# %%
first_level_output_df.head()
# Out:
#      subj vroinames  eccrois       amp      mode     sigma
# 0  subj01        V1      1.0  1.391234  4.255927  2.596999
# 1  subj01        V1      2.0  2.628286  2.689560  3.043270
# 2  subj01        V1      3.0  2.846116  1.989767  2.623931
# 3  subj01        V1      4.0  3.611407  1.398192  2.249174
# 4  subj01        V1      5.0  2.783276  1.039952  2.631305

# %%
import get_preferred_period

# %%
merged_df.head()
# Out:
#      subj vroinames  eccrois  freq_lvl  avg_betas  local_ori   local_sf  \
# 0  subj01        V1      1.0         0   1.404251    1.54996   3.049521
# 1  subj01        V1      1.0         1   1.352611    1.54996   5.467465
# 2  subj01        V1      1.0         2   1.147461    1.54996  10.411715
# 3  subj01        V1      1.0         3   0.998912    1.57303  19.268526
# 4  subj01        V1      1.0         4   0.911174    1.54996  36.179394
#
#         amp      mode     sigma  y_lg_pdf
# 0  1.391234  4.255907  2.597004  1.367586
# 1  1.391234  4.255907  2.597004  1.377827
# 2  1.391234  4.255907  2.597004  1.229607
# 3  1.391234  4.255907  2.597004  0.978522
# 4  1.391234  4.255907  2.597004  0.686208

# %%
grid = get_preferred_period.plot_sfp(subj=subj_list, df=output_df, save_fig=True, save_file_name='all_subjs_with_previous_findings.png', n_sp_low=2) # alpha 0.13

# %%
merged_df
# Out:
#        subj vroinames  eccrois  freq_lvl  avg_betas  local_ori   local_sf  \
# 0    subj01        V1      1.0         0   1.404251   1.549960   3.049521
# 1    subj01        V1      1.0         1   1.352611   1.549960   5.467465
# 2    subj01        V1      1.0         2   1.147461   1.549960  10.411715
# 3    subj01        V1      1.0         3   0.998912   1.573030  19.268526
# 4    subj01        V1      1.0         4   0.911174   1.549960  36.179394
# ..      ...       ...      ...       ...        ...        ...        ...
# 955  subj08       V4v      5.0         1   2.198268   1.576913   0.309985
# 956  subj08       V4v      5.0         2   2.307881   1.576913   0.590306
# 957  subj08       V4v      5.0         3   2.327187   1.574371   1.092454
# 958  subj08       V4v      5.0         4   2.433624   1.576913   2.051238
# 959  subj08       V4v      5.0         5   2.519998   1.576913   3.807323
#
#           amp      mode     sigma  y_lg_pdf
# ...

# %%
output_df
# Out:
#        subj vroinames  eccrois       amp      mode     sigma
# 0    subj01        V1      1.0  1.391234  4.255907  2.597004
# 1    subj01        V1      2.0  2.628286  2.689563  3.043267
# 2    subj01        V1      3.0  2.846117  1.989767  2.623930
# 3    subj01        V1      4.0  3.611407  1.398192  2.249175
# 4    subj01        V1      5.0  2.783276  1.039965  2.631305
# ..      ...       ...      ...       ...       ...       ...
# 155  subj08       V4v      1.0  1.323576  0.545595  6.598586
# 156  subj08       V4v      2.0  1.115117  2.900108  4.811527
# 157  subj08       V4v      3.0  3.327445  3.684397  3.278052
# 158  subj08       V4v      4.0  2.650645  2.340895  3.656610
# 159  subj08       V4v      5.0  2.482606  3.125322  5.744349
#
# [160 rows x 6 columns]

# %%
pd.melt(output_df, id_vars=['subj', 'vroinames', 'eccrois'], value_vars=['amp', 'mode', 'sigma'], ignore_index=True).rename(columns={'variable':'params'})
# Out:
#        subj vroinames  eccrois params     value
# 0    subj01        V1      1.0    amp  1.391234
# 1    subj01        V1      2.0    amp  2.628286
# 2    subj01        V1      3.0    amp  2.846117
# 3    subj01        V1      4.0    amp  3.611407
# 4    subj01        V1      5.0    amp  2.783276
# ..      ...       ...      ...    ...       ...
# 475  subj08       V4v      1.0  sigma  6.598586
# 476  subj08       V4v      2.0  sigma  4.811527
# 477  subj08       V4v      3.0  sigma  3.278052
# 478  subj08       V4v      4.0  sigma  3.656610
# 479  subj08       V4v      5.0  sigma  5.744349
#
# [480 rows x 5 columns]

# %%
import plot_1D_model_results as plotting

# %%
plotting.plot_parameter_dist(output_df=output_df, save_fig=True)

# %%
len(output_df['subj'].unique())
# Out:
# 8

# %%
import sys
import os
import binning_eccen as binning
import pandas as pd

# %%
subj = 'subj01'
df_dir='/Volumes/server/Projects/sfp_nsd/natural-scenes-dataset/derivatives/subj_dataframes'
df_file_name='stim_voxel_info_df.csv'
df_path = os.path.join(df_dir, subj + '_' + df_file_name)
subj01_df = pd.read_csv(df_path)

# %%
subj01_df.head()
# Out:
#    stim_idx  voxel  fixation_task_betas  memory_task_betas  avg_betas hemi  \
# 0         0      0             1.096667           4.410000   2.753333   lh
# 1         0      1             1.056667           3.313333   2.185000   lh
# 2         0      2             0.826667           2.453333   1.640000   lh
# 3         0      3             1.640000           3.966667   2.803333   lh
# 4         0      4             1.716667           3.296667   2.506667   lh
#
#    visualrois vroinames  eccrois  eccentricity  ...  names_idx  w_r  w_a  \
# 0         2.0        V1      3.0      1.370705  ...          0  0.0  6.0
# 1         2.0        V1      3.0      1.270235  ...          0  0.0  6.0
# 2         2.0        V1      3.0      1.153417  ...          0  0.0  6.0
# 3         2.0        V1      3.0      1.270225  ...          0  0.0  6.0
# 4         2.0        V1      3.0      1.247216  ...          0  0.0  6.0
#
# ...
